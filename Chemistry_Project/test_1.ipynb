# %% [markdown]
# # EXAMPLE

# %%
import LAB
import numpy as np

# %% [markdown]
# ## Determination of pKa of Vinegar Using pH Sensor

# %%
g = LAB.PotentiometricConductionExperiments()
g.p_Ka('E:\\RLJIT\\SEM_2\\chemistry\\Project\\sample.csv', 6, 3, 4.75)

# %% [markdown]
# ______________________________________________________

# %% [markdown]
# ## Estimation of Copper Present in Electroplating Effluent by OD

# %%
cu = LAB.ConductionExperiments(None, None, None)
SO = cu.Estimation_of_Copper(np.linspace(5, 20, 4), np.array([.11, .21, .29, .39]))
SO
# Out:
# CSOLUTION  :
# Enter the Volume of the solution :  25
# 25.0ml of test solution contains 25.0x4 = 100.0mg of CuSO₄.5H₂O (Y)
# 249.65g of CuSO₄.5H₂O contains 63.54g of Cu
#
# Y mg of CuSO₄ contains :
# 63 x Y
# ──────
# 249.65
# 			=25.45163mg of copper

# %% [markdown]
# ______________________________

# %% [markdown]
# ## Determination of Viscosity coefficient of lubricant by Oswald's viscometer

# %%
v = LAB.ConductionExperiments(None,np.array([90,89,89,89]),np.array([118,117,117,117]))
v.Viscosity()
# Out:
# n₁t₂d₂
# ──────
#  t₁d₁
# Enter the lab temprature :  23
# Enter the lubricant number :  5
# CALCULATIONS :
# Enter the Viscosity coefficient of water(n₁) :  9.358
# Enter the density of water(d₁) :  0.9975
# Enter the density of lube(d₂) :  1.1038
# The Viscisity coefficient of liven lubricant at 23.0°C is 7.88235 millipoise
# ...

# %% [markdown]
# _____________________________

# %% [markdown]
# ## Determination of total hardness of water using salt of EDTA

# %%
W = LAB.ConductionExperiments(np.array([[13.2,0],[13,0],[13.5,0]]),None,None)
W.hardness()
# Out:
# Molarity of EDTA =
#
#        Weight of EDTA x4
# ────────────────────────────────
# Molecular weight of EDTA(372.14)
# Weight of the bottle + disodium salt of EDTA (W1) =  6.3881
# Weight of the bottle (W2) =  2.2103
# Weight of di sodium salt of EDTA = 4.1778
# Molarity of EDTA = 0.0449
# CALCULATIONS  :
#
#                Volume of EDTA = 13 cm³
# 1000cm³ 1M EDTA = 100g (Molecular mass of CaCO₃ = 100)
#
# 13 cm³ of 0.0449M of EDTA =
# 0.5942g of CaCO₃
#
# Total hardness of given water(25cm³) sample = 2376.80 ppm of CaCO₃
# ...

# %% [markdown]
# ____________________________

# %% [markdown]
# ## Determination of COD of the given industrial waste water sample

# %%
C = LAB.ConductionExperiments(np.array([[23,0],[23,0],[22.9,0]]),None,None)
C.Chemical_Oxygen_Demand()
# Out:
#         Weight of Mohr's salt x4
# ────────────────────────────────────────
# Molecular weight of Mohr's salt (372.14)
# Weight of the bottle + FAS (W1) =  10.7313
# Weight of the bottle (W2) =  4.11504
# Weight of di sodium salt of EDTA = 6.6163
#
# Molarity of EDTA = 0.0675
#
# CALCULATIONS  :
#
# volume of FAS consumed = 22.96666666666667
# Enter the Blank titrate value :  13
#
# 100cm³ of 1N Mohrs salt solution = 1 equivalent of oxygen
#                    			i.e, 8g of Oxygen
#
# COD of 13.0cm³ of 0.0675N of Mohr's salt solution is 215.28mg of oxygen/cm³
# ...

# %% [markdown]
# __________________________________

# %% [markdown]
# ## Estimation of iron in TMT bar by External Indicator method

# %%
T = LAB.ConductionExperiments(np.array([[6,0],[6,0],[5.8,0]]),None,None)
T.Iron_in_TMT()
# Out:
#       Weight of Potassium Dichromate x4
# ─────────────────────────────────────────────
# Molecular weight of Potassium Dichromate (49)
# Weight of the bottle + Potassium Dichromate (W1) =  6.4429
# Weight of the bottle (W2) =  4.1209
# Weight of di sodium salt of EDTA = 2.3220
#
# Molarity of EDTA = 0.1895
#
# CALCULATIONS  :
#
# volume of Potassium Dichromate consumed = 5.933333333333334
# Enter the weight of given TMT bar in 250cm³ of solution :  2
# 5.933333333333334cm³ of 0.18955N of Potassium Dichromate solution is 0.06276g of Fe
# Percentage of iron in the given 250g of TMT bar solution is 31.38%
# ...

# %% [markdown]
# ________________________
