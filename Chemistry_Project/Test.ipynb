# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sample.csv')
df
# Out:
#        pH  DelpH  volume  DelpH_v
# 0    3.69   0.35     0.5     0.70
# 1    4.05   0.36     1.0     0.72
# 2    4.30   0.25     1.5     0.50
# 3    4.45   0.15     2.0     0.30
# 4    4.58   0.13     2.5     0.26
# 5    4.75   0.17     3.0     0.34
# 6    4.92   0.17     3.5     0.34
# 7    5.05   0.13     4.0     0.26
# 8    5.25   0.20     4.5     0.40
# 9    5.53   0.28     5.0     0.56
# 10   5.95   0.42     5.5     0.84
# 11   8.75   2.80     6.0     5.60
# 12  11.30   2.55     6.5     5.10
# 13  11.82   0.52     7.0     1.04
# 14  12.03   0.21     7.5     0.42
# 15  12.15   0.12     8.0     0.24
# 16  12.25   0.10     8.5     0.20
# 17  12.32   0.07     9.0     0.14
# 18  12.40   0.08     9.5     0.16
# 19  12.45   0.05    10.0     0.10

# %%
f = plt.figure()
f.set_figwidth(18)
f.set_figheight(8)
plt.plot(df['volume'],df['pH'])
plt.xticks(df['volume'])
plt.show()

# %%
f = plt.figure()
f.set_figwidth(18)
f.set_figheight(8)
plt.plot(df['volume'],df['DelpH'])
plt.xticks(df['volume'])
plt.show()

# %%
f = plt.figure()
f.set_figwidth(18)
f.set_figheight(8)
plt.plot(df['volume'],df['DelpH_v'])
plt.xticks(df['volume'])
plt.show()

# %%
from sympy.vector import *
from sympy import *
N = CoordSys3D('N')
x = Symbol('X')
display()
# Out:
# N.x**2

# %%
A = Del()
A(N.x**2)
gradient(A)
# Out:
# 0

# %%
var('x,y')
p = x+2*y
q = x-2*y

diff(q,x)
diff(p,y)
integrate((diff(q,x)-diff(p,y)),[x,0,1],[y,0,1])
# Out:
# -1

# %%
np.zeros((2,3),dtype=int)
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
a = Symbol('a', real = True, positive = True)
var('t,s')
laplace_transform(sin(a*t),t,s,noconds = True)
# Out:
# a/(a**2 + s**2)

# %%
t,s,tau = symbols('t,s,tau')
f =t
g = exp(t)

f.subs({t:tau})
# Out:
# tau

# %%
f = lambdify(Symbol('x'), 'x + 1')
f(6)
# Out:
# 7
